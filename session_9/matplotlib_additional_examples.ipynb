# %% [markdown]
# # Matplotlib
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
# [Matplotlib](https://matplotlib.org/)
#
# - Create publication quality plots.
# - Make interactive figures that can zoom, pan, update.
# - Customize visual style and layout.
# - Export to many file formats.
# - Embed in JupyterLab and Graphical User Interfaces.
# - Use a rich array of third-party packages built on Matplotlib.

# %% [markdown]
# ## Addtional examples

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [20, 4]
plt.rcParams['figure.dpi'] = 100 

fig, ax = plt.subplots(1, 4, tight_layout=True)

# simple chart
x = np.linspace(0, 10, 100)
ax[0].plot(x, np.sin(x), '-', label="$sen(x)$")
ax[0].plot(x, np.cos(x), '--', label="$cos(x)$");
ax[0].set_title("$y(x) = sen(x)$ and $y(x) = cos(x)$")
ax[0].legend()

# chart from data points
x = np.sort(np.random.uniform(0,1,10))
y = x**2
ax[1].plot(x, y, 'o-');
ax[1].set_title("$(x,y)$ coordinates")

# scatter plot
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T
ax[2].scatter(features[0], features[1], alpha=0.4, s=300*features[3], c=iris.target);
ax[2].set_title("Scatter plot")
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %% [markdown]
# ### 3D charts

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.tri as mtri


fig = plt.figure(figsize=plt.figaspect(0.5))

# Make a mesh in the space of parameterisation variables u and v
u = np.linspace(0, 2.0 * np.pi, endpoint=True, num=50)
v = np.linspace(-0.5, 0.5, endpoint=True, num=10)
u, v = np.meshgrid(u, v)
u, v = u.flatten(), v.flatten()

# This is the Mobius mapping, taking a u, v pair and returning an x, y, z
# triple
x = (1 + 0.5 * v * np.cos(u / 2.0)) * np.cos(u)
y = (1 + 0.5 * v * np.cos(u / 2.0)) * np.sin(u)
z = 0.5 * v * np.sin(u / 2.0)

# Triangulate parameter space to determine the triangles
tri = mtri.Triangulation(u, v)

# Plot the surface.  The triangles in parameter space determine which x, y, z
# points are connected by an edge.
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.triangles, cmap=plt.cm.Spectral)
ax.set_zlim(-1, 1);

plt.rcParams['figure.figsize'] = [8, 4]
plt.rcParams['figure.dpi'] = 100 ;

# %% [markdown]
# # Another simple chart
#
# - A 2 D char is formed from a set of data points (coordinates) $(x,y)$.
# - Plot a char with the coordinates below
#
# | x | y  |
# |---|----|
# | 1 | 4  |
# | 2 | 10 |
# | 3 | 11 |
# | 4 | 7  |
# | 5 | 5  |

# %% [markdown]
# ### A simple method (step by step)
#
# 1a. Import numpy and matplotlib.pyplot (**once per session**).
#
# - **NumPy** is a package for the Python language that supports multidimensional arrays and matrices. Enables data manipulation in an efficient way. Data is passed to Matplotlib as Numpy arrays.
# - **matplotlib.pyplot** is a set of functions that allows you to make **Matplotlib** work like **MATLAB** (commercial software for computational mathematics).
#    - It is the almost standard method to use **Matplotlib**.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2a. Define the coordinates

# %%
x = [1, 2, 3, 4, 5]
y = [4, 10, 11, 7, 5]

# %% [markdown]
# 3a. Plot it!

# %%
plt.plot(x, y);

# %% [markdown]
# Complete code (py):
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# x = [1, 2, 3, 4, 5]
# y = [4, 10, 11, 7, 5]
# plt.plot(x, y);
# ```

# %% [markdown]
# - *format* `fmt` a convenient way to pass plot formatting in a string.
#
# `format = '[marker][line][color]'`
#
#
# [matplotlib - docs](https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
plt.plot(x, y, 'o:b');

# %% [markdown]
# ### Challenge 1
#
# Plot a data set (any 5 elements), where: y is twice x.
#
# Markers should be stars, dotted lines and green.

# %%
# Your answer here

# %% [markdown]
# #### Solution 1

# %% [markdown]
# ```python
# x = [1,2,3,4,5]
# y = [2,4,6,8,10]
# plt.plot(x, y, '*--g');
# ```

# %% [markdown]
# ### Mathematical operations with Numpy
#
# - Numpy would allow solving the previous Challenge in a simpler way.

# %%
# it may not work...

x = [1,2,3,4,5]
plt.plot(x, x*2, '*--g');

# x is a `list`. Python does not understand mathematical operations (eg *2) on `lists`
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13460\2082081615.py in <module>
#       2
#       3 x = [1,2,3,4,5]
# ----> 4 plt.plot(x, x*2, '*--g');
#       5
#       6 # x is a `list`. Python does not understand mathematical operations (eg *2) on `lists`
#
# c:\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# c:\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
# ...

# %% [markdown]
# Solution for mathematical operations with arrays: Numpy#!
#
# - Let's convert x from **list** to **numpy.array**.
# - This will allow you to do mathematical operations with the elements of **numpy.array**.

# %%
x = np.array([1,2,3,4,5])
plt.plot(x, x*2, '*--g');

# %% [markdown]
# [Numpy - documentation](https://numpy.org/doc/stable/)

# %% [markdown]
# ## Advance plotting with matplotlib.pyplot
#
# More than one plot in the same figure
#
# - When we do `plt.plot(...)`, two things happen under the hood:
#    - A figure is created.
#    - A pair of axes (x,y) is created inside the figure.
# - Creating the figure and axes on your own gives you more freedom to explore pyplot.

# %%
fig = plt.figure() # creats a figure
ax = plt.axes() # adds axes

# data
x = np.array([1,2,3,4,5])

# plot
ax.plot(x,3*x);

# %% [markdown]
# Adding another plot that shares the same axes:

# %%
fig = plt.figure() # creates a figure
ax = plt.axes() # adds axes

# data
x = np.array([1,2,3,4,5])

# 2 plots using the same axes
ax.plot(x,3*x)
ax.plot(x,x+2);

# %% [markdown]
# It's always a good idea to add labels...

# %%
fig = plt.figure() # creates a figure
ax = plt.axes() # adds axes

# data
x = np.array([1,2,3,4,5])

# 2 plots using the same axes, now with labels
ax.plot(x,3*x, label='y=3x')
ax.plot(x,x+2, label='y=x+2');

ax.legend();

# %% [markdown]
# #### You can also add a grid

# %%
fig = plt.figure() # creates picture
ax = plt.axes() # adds axes

# data
x = np.array([1,2,3,4,5])

# 2 plots using the same axes with labels
ax.plot(x,3*x, label='y=3x')
ax.plot(x,x+2, label='y=x+2');

ax.legend()

# adds the grid
ax.grid(c='r', alpha=0.4, linestyle='--');

# %% [markdown]
# What about adding a title?

# %%
fig = plt.figure() 
ax = plt.axes() 

# data
x = np.array([1,2,3,4,5])

# 2 plots 
ax.plot(x,3*x, label='y=3x')
ax.plot(x,x+2, label='y=x+2');

ax.legend()

ax.grid(c='r', alpha=0.4, linestyle='--')

ax.set_title("This is a test tile");

# %% [markdown]
# Adding labels to axes x and y

# %%
fig = plt.figure() 
ax = plt.axes() 

# data
x = np.array([1,2,3,4,5])

# 2 plots 
ax.plot(x,3*x, label='y=3x')
ax.plot(x,x+2, label='y=x+2');

ax.legend()

ax.grid(c='r', alpha=0.4, linestyle='--')

plt.title("A test title")

ax.set_xlabel("my x axis")
ax.set_ylabel("my y axis");

# %% [markdown]
# ### Several plots on the same picture

# %%
import numpy as np
import matplotlib.pyplot as plt


fig, ax = plt.subplots(2, 2)

# grafico 1
x = np.linspace(0, 10, 100)
ax[0][0].plot(x, np.sin(x), 'g-', label="$sen(x)$")
ax[0][0].set_title("$y(x) = sen(x)$")
ax[0][0].legend()

# grafico 2
x = np.linspace(0, 10, 100)
ax[1][0].plot(x, np.cos(x), 'r--', label="$cos(x)$");
ax[1][0].set_title("$y(x) = cos(x)$")
ax[1][0].legend();

# %% [markdown]
# ### Anatomy of a figure
#
# ![anatomy1.webp](data:image/webp;base64,...)

# %% [markdown]
# #### Challenge 2
#
# Graph the average temperature per year for the city of São Paulo, Manaus and Porto Alegre in Brazil
#
# [Data: http://en.tutiempo.net/climate](http://en.tutiempo.net/climate)
#
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ```python
# year_manaus = [1973, 1974, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1993, 1994, 1995, 1996, 1999, 2000, 2001, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
# temperature_manaus = [26.7, 26.4, 26.8, 26.8, 26.9, 27.0, 27.0, 26.8, 26.9, 27.3, 26.3, 26.5, 26.6, 27.5, 27.1, 26.7, 27.2, 27.3, 27.0, 27.1, 27.4, 27.0, 27.8, 27.3, 27.3, 27.6, 27.7, 27.2, 26.9, 26.9, 26.8, 27.9, 27.6, 27.2, 27.2, 27.4]
#
# year_porto_alegre = [1973, 1974, 1976, 1977, 1978, 1979, 1980, 1981, 1984, 1985, 1986, 1987, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2003, 2004, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
# temperature_porto_alegre = [19.9, 19.8, 19.3, 20.8, 19.9, 19.3, 20.1, 20.2, 20.0, 20.8, 20.6, 19.8, 19.2, 19.5, 19.8, 19.6, 19.9, 19.4, 19.2, 19.6, 19.0, 19.0, 19.6, 20.5, 20.3, 18.9, 20.3, 19.8, 19.6, 19.6, 19.7, 19.4, 20.6, 19.4, 20.7, 20.6, 19.6, 20.7, 20.1, 20.9]
#
# year_sao_paulo = [1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1993, 1994, 1995, 1996, 1999, 2000, 2001, 2003, 2004, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
# temperature_sao_paulo = [19.5, 19.1, 19.3, 18.9, 20.5, 19.6, 19.2, 20.0, 19.3, 19.3, 19.7, 20.2, 19.6, 20.1, 19.9, 19.4, 19.2, 20.1, 19.9, 20.3, 20.5, 19.8, 19.7, 20.1, 20.4, 21.2, 20.6, 19.4, 20.0, 20.4, 19.6, 20.0, 20.1, 19.7, 20.5, 20.0, 20.9, 20.9, 20.1, 20.2, 20.2, 20.8]
# ```

# %%
# your solution here
