# %% [markdown]
# # Project 2 – create a Jupyter notebook to analyse the Iris dataset

# %% [markdown]
# #### 1. Create a new Jupyter notebook and load the required libraries (pandas, numpy, matplotlib or seaborn or plotly)

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# #### 2. Download the iris dataset and read the data from a .csv or .sqlite file (database)

# %%
iris = pd.read_csv("C:\\C:\python-data-science-analytics-viz\\datasets\\Iris.csv")

# %% [markdown]
# #### 3. Print the type of the loaded dataset (you should expect it to be a pandas.core.frame.DataFrame

# %%
print (type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### 4. Print the shape of the dataset

# %%
print(iris.shape)
# Out:
# (150, 6)

# %% [markdown]
# #### 5. Use the describe function to describe some of the statistical properties of the data

# %%
print(iris.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #### 6. Print the first 20 data points (the head of the dataset)

# %%
print(iris.head(20))
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %% [markdown]
# #### 7. Print the last 20 data points (the tail of the dataset)

# %%
print(iris.tail(20))
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# ...

# %% [markdown]
# #### 8. Create 4 (four) histograms for each column (SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm) with each plot showing all 150 elements for each column

# %%
iris.hist()
plt.show()

# %% [markdown]
# #### 9. Create a scatterplot of the Iris dataset features

# %%
scatter_matrix(iris)
plt.show()

# %% [markdown]
# #### 10. Use the groupby method to determine the class distribution (you should group by 'species ')

# %%
species = iris.groupby("Species")["PetalLengthCm"].count()
print(species)
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: PetalLengthCm, dtype: int64

# %% [markdown]
# #### 11) Free mark: implement whichever additional analysis of this dataset you may want and demonstrate it (you should use additional functions or plot additional visualizations)
# #### Please add your code below!
